# %%
import pandas as pd
from skimpy import skim

# %%
df = pd.read_csv("https://drive.google.com/uc?id=1oE-3rt17bFW7fOzDIjwFSEMPTIV3NvcO")

# %%
skim(df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 1510   │ │ float64     │ 6     │                                                          │
# │ │ Number of columns │ 14     │ │ int64       │ 5     │                                                          │
# │ └───────────────────┴────────┘ │ string      │ 3     │                                                          │
# │                                └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━━━━┳━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━━┳━━━━━━━━┓  │
# │ ┃ column          ┃ NA ┃ NA %           ┃ mean   ┃ sd     ┃ p0     ┃ p25   ┃ p50   ┃ p75   ┃ p100   ┃ hist   ┃  │
# │ ┡━━━━━━━━━━━━━━━━━╇━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━━╇━━━━━━━━┩  │
# │ │    school_id    │  0 │              0 │  457.3 │  315.7 │     57 │   141 │   458 │   812 │    946 │ █▃█  █ │  │
# │ │      grade      │  0 │              0 │  7.037 │ 0.8173 │      6 │     6 │     7 │     8 │      8 │ ▇  █ █ │  │
# │ │       sex       │  0 │              0 │  1.203 │ 0.4026 │      1 │     1 │     1 │     1 │      2 │ █    ▂ │  │
# │ │   nationality   │  0 │              0 │  1.195 │ 0.3966 │      1 │     1 │     1 │     1 │      2 │ █    ▂ │  │
# │ │  grade_math_t1  │  0 │              0 │  6.654 │  1.701 │      0 │ 5.563 │  6.83 │ 7.944 │     10 │  ▁▃▇█▄ │  │
# │ │ grade_language_ │  0 │              0 │  6.628 │  1.713 │ 0.9938 │  5.53 │ 6.776 │ 7.852 │     10 │  ▂▄██▄ │  │
# │ │       t1        │    │                │        │        │        │       │       │       │        │        │  │
# │ │ grade_science_t │  0 │              0 │  6.642 │  1.698 │      0 │ 5.472 │ 6.758 │ 7.921 │     10 │  ▁▃▇█▄ │  │
# │ │        1        │    │                │        │        │        │       │       │       │        │        │  │
# │ │  grade_math_t2  │  2 │ 0.132450331125 │  205.9 │   4457 │      0 │ 5.635 │ 7.106 │ 8.387 │ 100000 │   █    │  │
# │ │                 │    │          82782 │        │        │        │       │       │       │        │        │  │
# │ │ grade_language_ │  3 │ 0.198675496688 │  139.6 │   3641 │      0 │ 5.602 │ 7.058 │ 8.358 │ 100000 │   █    │  │
# │ │       t2        │    │           7417 │        │        │        │       │       │       │        │        │  │
# │ │ grade_science_t │  2 │ 0.132450331125 │  205.8 │   4457 │      0 │ 5.677 │ 7.025 │ 8.406 │ 100000 │   █    │  │
# │ │        2        │    │          82782 │        │        │        │       │       │       │        │        │  │
# │ │    treatment    │  0 │              0 │ 0.5013 │ 0.5002 │      0 │     0 │     1 │     1 │      1 │ █    █ │  │
# │ └─────────────────┴────┴────────────────┴────────┴────────┴────────┴───────┴───────┴───────┴────────┴────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━┳━━━━┳━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━┓  │
# │ ┃           ┃    ┃      ┃           ┃           ┃           ┃           ┃ chars per ┃ words per ┃ total      ┃  │
# │ ┃ column    ┃ NA ┃ NA % ┃ shortest  ┃ longest   ┃ min       ┃ max       ┃ row       ┃ row       ┃ words      ┃  │
# │ ┡━━━━━━━━━━━╇━━━━╇━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━┩  │
# │ │   class   │  0 │    0 │     A     │     A     │     A     │     D     │         1 │         1 │       1510 │  │
# │ │ student_i │  0 │    0 │ wvqgd@cun │ wvqgd@cun │ 07cot@cun │ zyjey@cun │        14 │         1 │       1510 │  │
# │ │     d     │    │      │   b.edu   │   b.edu   │   b.edu   │   b.edu   │           │           │            │  │
# │ │ date_of_b │  0 │    0 │ 1997-07-2 │ 1997-07-2 │ 1994-09-0 │ 1997.03.0 │        10 │         1 │       1510 │  │
# │ │   irth    │    │      │     7     │     7     │     1     │     9     │           │           │            │  │
# │ └───────────┴────┴──────┴───────────┴───────────┴───────────┴───────────┴───────────┴───────────┴────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯
