# %% [markdown]
# Keep from your current content:
#
# .merge() (inner, left, right, outer)
#
# .concat() (axis=0 and axis=1)
#
# .join()
#
# Your hierarchical index examples with keys
#
#
# What to add:
#
# Merging on index vs columns
#
# Indicator parameter in merge
#
# Validating merges (one-to-one, one-to-many, etc.)
#
# Handling duplicate column names (suffixes)
#
# .combine_first()
#
# Cross join example
#
#
# What to remove: The cartesian/cross join section is good but could be simplified
