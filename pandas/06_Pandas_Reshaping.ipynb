# %% [markdown]
# Keep from your current content:
#
# .pivot() and .pivot_table()
#
# .melt() (unpivot)
#
# Your temperature pivot example
#
#
# What to add:
#
# .stack() and .unstack()
#
# .crosstab()
#
# Wide to long and long to wide transformations
#
# Multi-index pivoting
#
# .explode() for lists in cells
