# %%
import pandas as pd
from summarytools import dfSummary

# %%
df = pd.read_csv("https://drive.google.com/uc?id=1oE-3rt17bFW7fOzDIjwFSEMPTIV3NvcO")

# %%
df.replace({99999.0: pd.NA}, inplace=True)
df.dropna(inplace=True)

# %%
dfSummary(df, is_collapsible = True)
# Out:
# <button type="button" class = "st-collapsible",
#     id = "btn-4437" onclick = "coll_toggle_4437()">Show Summary - df</button>
#     <div class="st-content" id="cont-4437">
#       <style type="text/css">
# #T_eb111 thead>tr>th {
#   text-align: left;
# }
# #T_eb111_row0_col0, #T_eb111_row1_col0, #T_eb111_row2_col0, #T_eb111_row3_col0, #T_eb111_row4_col0, #T_eb111_row5_col0, #T_eb111_row6_col0, #T_eb111_row7_col0, #T_eb111_row8_col0, #T_eb111_row9_col0, #T_eb111_row10_col0, #T_eb111_row11_col0, #T_eb111_row12_col0, #T_eb111_row13_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_eb111_row0_col1, #T_eb111_row1_col1, #T_eb111_row2_col1, #T_eb111_row3_col1, #T_eb111_row4_col1, #T_eb111_row5_col1, #T_eb111_row6_col1, #T_eb111_row7_col1, #T_eb111_row8_col1, #T_eb111_row9_col1, #T_eb111_row10_col1, #T_eb111_row11_col1, #T_eb111_row12_col1, #T_eb111_row13_col1 {
#   text-align: left;
# ...

# %%
jupyter nbconvert --to html_embed path/of/your/notebook.ipynb
