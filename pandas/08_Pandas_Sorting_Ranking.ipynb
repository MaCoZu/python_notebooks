# %% [markdown]
# New notebook - content to add:
#
# .sort_values() (single and multiple columns)
#
# .sort_index()
#
# .rank() and ranking methods
#
# .nlargest(), .nsmallest()
#
# Custom sorting with key functions
#
#
#
# 09_Pandas_Time_Series.ipynb
#
# Keep from your current content:
#
# pd.date_range()
#
# Basic date operations
#
#
# What to add:
#
#
# Working with datetime index
#
# .resample() for time-based aggregation
#
# .shift(), .diff()
#
# Time zone handling
#
# Period and Timedelta
#
# Rolling windows for time series
#
# Date parsing and formatting
