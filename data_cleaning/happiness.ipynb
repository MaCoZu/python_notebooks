# %%
import pandas as pd

# %%
df = pd.read_csv('../Data/happiness.csv')
df[:3]
# Out:
#         Entity Code  Year  Cantril ladder score
# 0  Afghanistan  AFG  2011                 4.258
# 1  Afghanistan  AFG  2012                 4.040
# 2  Afghanistan  AFG  2014                 3.575

# %%
df_rename = df.copy()
df_rename.columns = ['Country', 'Code', 'Year', 'Happiness Score']
df_rename[:3]
# Out:
#        Country Code  Year  Happiness Score
# 0  Afghanistan  AFG  2011            4.258
# 1  Afghanistan  AFG  2012            4.040
# 2  Afghanistan  AFG  2014            3.575

# %%
df_rename.Year.unique()
# Out:
# array([2011, 2012, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022,
#        2023, 2024])

# %%
df_rename.to_csv('../Data/happiness_clean.csv', index=False)
