# %%
import pandas as pd

# %%
data = pd.read_csv('../Data/Footprint_SDG_HDI.csv', encoding='latin-1')
data.head()
# Out:
#                Country Data Quality  SDGi Life Exectancy   HDI Per Capita GDP  \
# 0          Afghanistan           3A  51.8             64  0.49         $2,440
# 1              Albania           3A  71.5             79  0.81        $13,863
# 2              Algeria           3A  70.5             76  0.75        $11,412
# 3               Angola           3A  51.0             62  0.60         $7,035
# 4  Antigua and Barbuda           2B   NaN             79  0.80        $22,000
#
#                       Region Income Group Population (millions)  \
# 0   Middle East/Central Asia           LI                 38.0
# 1               Other Europe           UM                  2.9
# 2                     Africa           UM                 43.1
# 3                     Africa           LM                 31.8
# 4  Central America/Caribbean           HI                  0.1
#
#    Cropland Footprint  ...  Total Ecological Footprint (Consumption)  \
# 0                 0.4  ...                                       0.9
# 1                 0.6  ...                                       2.1
# 2                 0.4  ...                                       2.4
# 3                 0.2  ...                                       1.0
# 4                 NaN  ...                                       3.9
#
#    Cropland  Grazing land  Forest land  Fishing ground  Built up land.2  \
# 0       0.4           0.2          0.0             0.0              0.0
# 1       0.6           0.2          0.2             0.1              0.1
# 2       0.4           0.2          0.0             0.0              0.0
# 3       0.2           0.9          0.5             0.2              0.1
# 4       NaN           NaN          NaN             NaN              NaN
#
#    Total biocapacity   Ecological (Deficit) or Reserve  \
# 0                 0.6                            (0.3)
# 1                 1.1                            (1.0)
# 2                 0.7                            (1.7)
# 3                 1.7                             0.7
# 4                 0.9                            (3.0)
#
#    Number of Earths required  Number of Countries required
# 0                        0.6                           1.5
# 1                        1.4                           1.9
# 2                        1.5                           3.4
# 3                        0.6                           0.6
# 4                        2.5                           4.2
#
# [5 rows x 32 columns]

# %%
data.columns
# Out:
# Index(['Country', 'Data Quality', 'SDGi', 'Life Exectancy', 'HDI',
#        'Per Capita GDP', 'Region', 'Income Group', 'Population (millions)',
#        'Number of Earths required'],
#       dtype='object')

# %%
data_new = data[
    [
        'Country',
        'Region',
        'Population (millions)',
        'Income Group',
        'HDI',
        'Life Exectancy',
        'Per Capita GDP',
        'SDGi',
        'Number of Earths required',
        'Data Quality',
    ]
]
data_new.head()
# Out:
#                Country                     Region Population (millions)  \
# 0          Afghanistan   Middle East/Central Asia                 38.0
# 1              Albania               Other Europe                  2.9
# 2              Algeria                     Africa                 43.1
# 3               Angola                     Africa                 31.8
# 4  Antigua and Barbuda  Central America/Caribbean                  0.1
#
#   Income Group   HDI Life Exectancy Per Capita GDP  SDGi  \
# 0           LI  0.49             64         $2,440  51.8
# 1           UM  0.81             79        $13,863  71.5
# 2           UM  0.75             76        $11,412  70.5
# 3           LM  0.60             62         $7,035  51.0
# 4           HI  0.80             79        $22,000   NaN
#
#    Number of Earths required Data Quality
# 0                        0.6           3A
# 1                        1.4           3A
# 2                        1.5           3A
# 3                        0.6           3A
# 4                        2.5           2B

# %% [markdown]
# # Remove $

# %%
# Remove the dollar signs and convert the column to float
# Remove the dollar signs, commas, and spaces, and convert to numeric
dataa = data_new.copy()
dataa['Per Capita GDP'] = (
    data['Per Capita GDP']
    .str.replace('$', '', regex=False)
    .str.replace(',', '', regex=False)
    .str.strip()
)

# %%
dataa.rename(columns={'Per Capita GDP': 'Per Capita GDP in $'}, inplace=True)
dataa.head()
# Out:
#                Country                     Region Population (millions)  \
# 0          Afghanistan   Middle East/Central Asia                 38.0
# 1              Albania               Other Europe                  2.9
# 2              Algeria                     Africa                 43.1
# 3               Angola                     Africa                 31.8
# 4  Antigua and Barbuda  Central America/Caribbean                  0.1
#
#   Income Group   HDI Life Exectancy Per Capita GDP in $  SDGi  \
# 0           LI  0.49             64                2440  51.8
# 1           UM  0.81             79               13863  71.5
# 2           UM  0.75             76               11412  70.5
# 3           LM  0.60             62                7035  51.0
# 4           HI  0.80             79               22000   NaN
#
#    Number of Earths required Data Quality
# 0                        0.6           3A
# 1                        1.4           3A
# 2                        1.5           3A
# 3                        0.6           3A
# 4                        2.5           2B

# %%
dataa.to_csv('../Data/footprint_clean.csv')

# %% [markdown]
# # Data types

# %%
data.dtypes
# Out:
# Country                                      object
# Data Quality                                 object
# SDGi                                         object
# Life Exectancy                               object
# HDI                                          object
# Per Capita GDP                               object
# Region                                       object
# Income Group                                 object
# Population (millions)                        object
# Cropland Footprint                          float64
# Grazing Footprint                           float64
# Forest Product Footprint                    float64
# Carbon Footprint                            float64
# Fish Footprint                              float64
# Built up land                               float64
# Total Ecological Footprint (Production)     float64
# Cropland Footprint.1                        float64
# Grazing Footprint.1                         float64
# Forest Product Footprint.1                  float64
# Carbon Footprint.1                          float64
# Fish Footprint.1                            float64
# Built up land.1                             float64
# Total Ecological Footprint (Consumption)    float64
# Cropland                                    float64
# Grazing land                                float64
# Forest land                                 float64
# Fishing ground                              float64
# Built up land.2                             float64
# Total biocapacity                           float64
# Ecological (Deficit) or Reserve              object
# Number of Earths required                   float64
# Number of Countries required                float64
# dtype: object

# %%
data[
    [
        'SDGi',
        'Life Exectancy',
        'HDI',
        'Per Capita GDP',
        'Population (millions)',
        'Number of Earths required',
    ]
] = data[
    [
        'SDGi',
        'Life Exectancy',
        'HDI',
        'Per Capita GDP',
        'Population (millions)',
        'Number of Earths required',
    ]
].apply(pd.to_numeric, errors='coerce')

# %%
data[['Data Quality', 'Region', 'Income Group']] = data[
    ['Data Quality', 'Region', 'Income Group']
].astype('category')
data[['Country']] = data[['Country']].astype('str')

# %%
data.dtypes
# Out:
# Country                                       object
# Data Quality                                category
# SDGi                                         float64
# Life Exectancy                               float64
# HDI                                          float64
# Per Capita GDP                               float64
# Region                                      category
# Income Group                                category
# Population (millions)                        float64
# Cropland Footprint                           float64
# Grazing Footprint                            float64
# Forest Product Footprint                     float64
# Carbon Footprint                             float64
# Fish Footprint                               float64
# Built up land                                float64
# Total Ecological Footprint (Production)      float64
# Cropland Footprint.1                         float64
# Grazing Footprint.1                          float64
# Forest Product Footprint.1                   float64
# Carbon Footprint.1                           float64
# Fish Footprint.1                             float64
# Built up land.1                              float64
# Total Ecological Footprint (Consumption)     float64
# Cropland                                     float64
# Grazing land                                 float64
# Forest land                                  float64
# Fishing ground                               float64
# Built up land.2                              float64
# Total biocapacity                            float64
# Ecological (Deficit) or Reserve               object
# Number of Earths required                    float64
# Number of Countries required                 float64
# dtype: object

# %% [markdown]
# # Save csv

# %%
data.to_csv('../Data/footprint_clean.csv', encoding='utf-8')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Country                    182 non-null    object
#  1   Data Quality               182 non-null    category
#  2   SDGi                       158 non-null    float64
#  3   Life Exectancy             175 non-null    float64
#  4   HDI                        171 non-null    float64
#  5   Per Capita GDP             163 non-null    float64
#  6   Region                     182 non-null    category
#  7   Income Group               178 non-null    category
#  8   Population (millions)      180 non-null    float64
#  9   Number of Earths required  181 non-null    float64
# dtypes: category(3), float64(6), object(1)
# memory usage: 11.5+ KB

# %% [markdown]
# # Regions ?

# %%
data.loc[(data['Region'] == 'Europe')]
data.Region.unique()
# Out:
# ['Middle East/Central Asia', 'Other Europe', 'Africa', 'Central America/Caribbean', 'South America', 'Asia-Pacific', 'EU-27', 'North America']
# Categories (8, object): ['Africa', 'Asia-Pacific', 'Central America/Caribbean', 'EU-27', 'Middle East/Central Asia', 'North America', 'Other Europe', 'South America']

# %%
data.groupby('Region', observed=False).size()
# Out:
# Region
# Africa                       53
# Asia-Pacific                 30
# Central America/Caribbean    20
# EU-27                        26
# Middle East/Central Asia     23
# North America                 4
# Other Europe                 13
# South America                13
# dtype: int64

# %% [markdown]
# # Countries with missing data

# %%
# Out:
#                                    Country Data Quality  SDGi  Life Exectancy  \
# 89  Korea, Democratic People's Republic of           3A   NaN            73.0
#
#     HDI  Per Capita GDP        Region Income Group  Population (millions)  \
# 89  NaN             NaN  Asia-Pacific           LI                   26.0
#
#     Number of Earths required
# 89                        0.8

# %%
data.loc[data.isnull().any(axis=1)]
data.loc[data.Country == "Korea, Democratic People's Republic of"]
list(data.loc[(data['HDI'].isnull())]['Country'])
data.loc[(data['HDI'].isnull())][['Country', 'Number of Earths required']].sort_values(
    'Number of Earths required'
)
# Out:
#                                     Country  Number of Earths required
# 40                            Côte d'Ivoire                        0.6
# 150                                 Somalia                        0.6
# 181                                Zimbabwe                        0.7
# 89   Korea, Democratic People's Republic of                        0.8
# 180                                  Zambia                        0.8
# 60                            French Guiana                        1.0
# 105                              Martinique                        2.3
# 69                               Guadeloupe                        2.3
# 134                                 Réunion                        2.3
# 61                         French Polynesia                        2.5
# 17                                  Bermuda                        NaN

# %%
# How many are just sustainable
data.loc[(data['Number of Earths required'] <= 1)]['Population (millions)'].sum()

# Just sustainable people as %

# # of countries that are sustainable
data.loc[(data['Number of Earths required'] <= 1)].count()
data.loc[(data['Number of Earths required'] <= 1)][
    'Population (millions)'
].sum() / data['Population (millions)'].sum()
# Out:
# np.float64(0.40393569183015626)

# %% [markdown]
# # Who's sustainable and developed

# %%
# suatainable and developed countries
data.loc[(data['HDI'] > 0.7) & (data['Number of Earths required'] <= 1)]

# In population  numbers
data.loc[(data['HDI'] > 0.7) & (data['Number of Earths required'] <= 1)][
    'Population (millions)'
].sum()

# Suatainable and developed people as percentage
data.loc[(data['HDI'] > 0.7) & (data['Number of Earths required'] <= 1)][
    'Population (millions)'
].sum() / data['Population (millions)'].sum()
# Out:
# np.float64(0.026363961956305457)

# %%
# Unsustainable world population %
data.loc[(data['Number of Earths required'] > 1)]['Population (millions)'].sum() / data[
    'Population (millions)'
].sum()
# Out:
# np.float64(0.5960444108400651)

# %%
# Sustainable countries sorted by HDI
data.loc[(data['Number of Earths required'] <= 1)].sort_values('HDI', ascending=False)[
    :5
]
# Out:
#                  Country Data Quality  SDGi  Life Exectancy   HDI  \
# 132  Republic of Moldova           2B  73.9            69.0  0.77
# 50                 Egypt           2B  68.7            70.0  0.73
# 166              Tunisia           2A  70.7            74.0  0.73
# 86                Jordan           2A  69.4            74.0  0.72
# 128          Philippines           3A  66.6            69.0  0.70
#
#      Per Capita GDP                    Region Income Group  \
# 132         14320.0              Other Europe           LM
# 50          12786.0                    Africa           LM
# 166         10535.0                    Africa           UM
# 86          10159.0  Middle East/Central Asia           UM
# 128          8768.0              Asia-Pacific           LM
#
#      Population (millions)  Number of Earths required
# 132                    4.0                        1.0
# 50                   106.2                        1.0
# 166                   12.0                        0.9
# 86                    10.3                        0.9
# 128                  112.5                        0.8

# %%
data.loc[(data['Number of Earths required'] <= 1)].groupby(
    'Region', observed=False
).size()
# Out:
# Region
# Africa                       39
# Asia-Pacific                 10
# Central America/Caribbean     3
# EU-27                         0
# Middle East/Central Asia      6
# North America                 0
# Other Europe                  1
# South America                 1
# dtype: int64

# %%
data.loc[(data['Number of Earths required'] <= 1)].groupby(
    'Income Group', observed=False
).size()
# Out:
# Income Group
# HI     0
# LI    34
# LM    23
# UM     2
# dtype: int64

# %%
data.loc[(data['HDI'] > 0.7) & (data['Number of Earths required'] <= 1)]['Country']
# Out:
# 50                   Egypt
# 86                  Jordan
# 132    Republic of Moldova
# 166                Tunisia
# Name: Country, dtype: object
