# %% [markdown]
# # Pandas Transformations

# %% [markdown]
# Keep from your current content:
#
# Adding columns (calculated columns)
#
# .apply(), .map(), .applymap()
#
# If/Then logic with np.where()
#
# Lambda functions
#
# Conditional column creation
#
# What to add:
#
# .assign() for chaining
#
# .pipe() for custom functions
#
# .transform() vs .apply()
#
# Window functions: .rolling(), .expanding()
#
# Binning: pd.cut(), pd.qcut()

# %%
import pandas as pd

# %%
df = pd.read_csv("https://drive.google.com/uc?id=1oE-3rt17bFW7fOzDIjwFSEMPTIV3NvcO")
df[:3]
# Out:
#    school_id  grade class      student_id  sex  nationality  grade_math_t1  \
# 0         57      6     A  wvqgd@cunb.edu    1            1       2.046285
# 1         57      6     A  j0ihe@cunb.edu    1            2       7.859077
# 2         57      6     A  wcjgk@cunb.edu    2            1       7.118976
#
#    grade_language_t1  grade_science_t1  grade_math_t2  grade_language_t2  \
# 0           2.369783          2.711344       1.175309           1.498807
# 1           7.206984          6.994455       7.548812           6.896719
# 2           8.057449          8.573210       6.181019           7.119492
#
#    grade_science_t2  treatment date_of_birth
# 0          1.840368          1    1997-07-27
# 1          6.684190          1    1997-06-24
# 2          7.635253          1    1997-04-23

# %% [markdown]
# ## calculated columns
#
# - Direct operations on entire columns is the fastest vectorized way to manipulate data in pandas.
# - optimized C/NumPy backend
# - For simple arithmetic, logical, or string operations (+, *, sum(), str.upper()) on columns.

# %%
df_a = df.copy()
df_a["math_avg"] = df_a[["grade_math_t1", "grade_math_t2"]].mean(axis=1)a
# Out:
#       school_id  grade class      student_id  sex  nationality   math_t1  \
# 0            57      6     A  wvqgd@cunb.edu    1            1  2.046285
# 1            57      6     A  j0ihe@cunb.edu    1            2  7.859077
# 2            57      6     A  wcjgk@cunb.edu    2            1  7.118976
# 3            57      6     A  mzmqb@cunb.edu    1            1  6.973737
# 4            57      6     A  s6n0y@cunb.edu    1            1  6.574877
# ...         ...    ...   ...             ...  ...          ...       ...
# 1505        946      8     D  jj36e@cunb.edu    1            1  4.938375
# 1506        946      8     D  ca1dg@cunb.edu    1            1  7.661931
# 1507        946      8     D  amdrx@cunb.edu    1            1  9.248758
# 1508        946      8     D  yn5ug@cunb.edu    1            2  5.689228
# 1509        946      8     A  eohgp@cunb.edu    1            1  9.768719
#
#       language_t1  science_t1   math_t2  language_t2  science_t2  treatment  \
# 0        2.369783    2.711344  1.175309     1.498807    1.840368          1
# 1        7.206984    6.994455  7.548812     6.896719    6.684190          1
# 2        8.057449    8.573210  6.181019     7.119492    7.635253          1
# 3        7.388008    6.628448  7.593102     8.007373    7.247812          1
# 4        6.773626    7.844316  7.611065     7.809814    8.880504          1
# ...           ...         ...       ...          ...         ...        ...
# 1505     5.306647    4.985917  6.162418     6.530690    6.209960          0
# 1506     8.360153    7.937165  8.179364     8.877586    8.454598          0
# 1507     8.534791    8.056641  8.773601     8.059634    7.581484          0
# 1508     5.071503    5.338547  6.382995     5.765270    6.032315          0
# 1509    10.000000    8.493072  9.515601     9.746882    8.239953          0
#
#      date_of_birth  math_avg
# 0       1997-07-27  1.610797
# 1       1997-06-24  7.703944
# 2       1997-04-23  6.649997
# 3       1997-02-24  7.283419
# 4       1996-09-05  7.092971
# ...            ...       ...
# 1505    1995-07-04  5.550397
# 1506    1995-08-23  7.920647
# 1507    1994-12-15  9.011180
# 1508    1994-09-18  6.036111
# 1509    1994-12-19  9.642160
#
# [1510 rows x 15 columns]

# %% [markdown]
# ## column renaming and sorting

# %%
df_a[:3]
# Out:
#    school_id  grade class      student_id  sex  nationality  math_avg  \
# 0         57      6     A  wvqgd@cunb.edu    1            1  1.610797
# 1         57      6     A  j0ihe@cunb.edu    1            2  7.703944
# 2         57      6     A  wcjgk@cunb.edu    2            1  6.649997
#
#     math_t1  language_t1  science_t1   math_t2  language_t2  science_t2  \
# 0  2.046285     2.369783    2.711344  1.175309     1.498807    1.840368
# 1  7.859077     7.206984    6.994455  7.548812     6.896719    6.684190
# 2  7.118976     8.057449    8.573210  6.181019     7.119492    7.635253
#
#    treatment date_of_birth
# 0          1    1997-07-27
# 1          1    1997-06-24
# 2          1    1997-04-23

# %%
df_a.columns = df_a.columns.str.lower().str.replace("grade_", "")
df_a
# Out:
#       school_id  grade class      student_id  sex  nationality   math_t1  \
# 0            57      6     A  wvqgd@cunb.edu    1            1  2.046285
# 1            57      6     A  j0ihe@cunb.edu    1            2  7.859077
# 2            57      6     A  wcjgk@cunb.edu    2            1  7.118976
# 3            57      6     A  mzmqb@cunb.edu    1            1  6.973737
# 4            57      6     A  s6n0y@cunb.edu    1            1  6.574877
# ...         ...    ...   ...             ...  ...          ...       ...
# 1505        946      8     D  jj36e@cunb.edu    1            1  4.938375
# 1506        946      8     D  ca1dg@cunb.edu    1            1  7.661931
# 1507        946      8     D  amdrx@cunb.edu    1            1  9.248758
# 1508        946      8     D  yn5ug@cunb.edu    1            2  5.689228
# 1509        946      8     A  eohgp@cunb.edu    1            1  9.768719
#
#       language_t1  science_t1   math_t2  language_t2  science_t2  treatment  \
# 0        2.369783    2.711344  1.175309     1.498807    1.840368          1
# 1        7.206984    6.994455  7.548812     6.896719    6.684190          1
# 2        8.057449    8.573210  6.181019     7.119492    7.635253          1
# 3        7.388008    6.628448  7.593102     8.007373    7.247812          1
# 4        6.773626    7.844316  7.611065     7.809814    8.880504          1
# ...           ...         ...       ...          ...         ...        ...
# 1505     5.306647    4.985917  6.162418     6.530690    6.209960          0
# 1506     8.360153    7.937165  8.179364     8.877586    8.454598          0
# 1507     8.534791    8.056641  8.773601     8.059634    7.581484          0
# 1508     5.071503    5.338547  6.382995     5.765270    6.032315          0
# 1509    10.000000    8.493072  9.515601     9.746882    8.239953          0
#
#      date_of_birth  math_avg
# 0       1997-07-27  1.610797
# 1       1997-06-24  7.703944
# 2       1997-04-23  6.649997
# 3       1997-02-24  7.283419
# 4       1996-09-05  7.092971
# ...            ...       ...
# 1505    1995-07-04  5.550397
# 1506    1995-08-23  7.920647
# 1507    1994-12-15  9.011180
# 1508    1994-09-18  6.036111
# 1509    1994-12-19  9.642160
#
# [1510 rows x 15 columns]

# %%
df_a = df_a[[ 
    "school_id",
    "grade",
    "class",
    "student_id",
    "sex",
    "nationality",
    "math_avg",
    "math_t1",
    "language_t1",
    "science_t1",
    "math_t2",
    "language_t2",
    "science_t2",
    "treatment",
    "date_of_birth",
]]
df_a
# Out:
#       school_id  grade class      student_id  sex  nationality  math_avg  \
# 0            57      6     A  wvqgd@cunb.edu    1            1  1.610797
# 1            57      6     A  j0ihe@cunb.edu    1            2  7.703944
# 2            57      6     A  wcjgk@cunb.edu    2            1  6.649997
# 3            57      6     A  mzmqb@cunb.edu    1            1  7.283419
# 4            57      6     A  s6n0y@cunb.edu    1            1  7.092971
# ...         ...    ...   ...             ...  ...          ...       ...
# 1505        946      8     D  jj36e@cunb.edu    1            1  5.550397
# 1506        946      8     D  ca1dg@cunb.edu    1            1  7.920647
# 1507        946      8     D  amdrx@cunb.edu    1            1  9.011180
# 1508        946      8     D  yn5ug@cunb.edu    1            2  6.036111
# 1509        946      8     A  eohgp@cunb.edu    1            1  9.642160
#
#        math_t1  language_t1  science_t1   math_t2  language_t2  science_t2  \
# 0     2.046285     2.369783    2.711344  1.175309     1.498807    1.840368
# 1     7.859077     7.206984    6.994455  7.548812     6.896719    6.684190
# 2     7.118976     8.057449    8.573210  6.181019     7.119492    7.635253
# 3     6.973737     7.388008    6.628448  7.593102     8.007373    7.247812
# 4     6.574877     6.773626    7.844316  7.611065     7.809814    8.880504
# ...        ...          ...         ...       ...          ...         ...
# 1505  4.938375     5.306647    4.985917  6.162418     6.530690    6.209960
# 1506  7.661931     8.360153    7.937165  8.179364     8.877586    8.454598
# 1507  9.248758     8.534791    8.056641  8.773601     8.059634    7.581484
# 1508  5.689228     5.071503    5.338547  6.382995     5.765270    6.032315
# 1509  9.768719    10.000000    8.493072  9.515601     9.746882    8.239953
#
#       treatment date_of_birth
# 0             1    1997-07-27
# 1             1    1997-06-24
# 2             1    1997-04-23
# 3             1    1997-02-24
# 4             1    1996-09-05
# ...         ...           ...
# 1505          0    1995-07-04
# 1506          0    1995-08-23
# 1507          0    1994-12-15
# 1508          0    1994-09-18
# 1509          0    1994-12-19
#
# [1510 rows x 15 columns]

# %% [markdown]
# ## map()
#
# - Element-wise transformation of a Series (single column) using a dictionary, Series, or function.
# - Only works on Series (not DataFrames).
# - Useful for replacing values or simple lookups.
# - Faster than apply() for Series, but slower than vectorized operations.

# %%
# Map values using a dictionary
df_b = df_a.copy()
df_b["sex_coded"] = df_b["sex"].map({1: "male", 2: "female"})

df_b = df_b[
    [
        "school_id",
        "grade",
        "class",
        "student_id",
        "sex",
        "sex_coded",
        "nationality",
        "math_avg",
        "math_t1",
        "language_t1",
        "science_t1",
        "math_t2",
        "language_t2",
        "science_t2",
        "treatment",
        "date_of_birth",
    ]
]
df_b
# Out:
#       school_id  grade class      student_id  sex sex_coded  nationality  \
# 0            57      6     A  wvqgd@cunb.edu    1      male            1
# 1            57      6     A  j0ihe@cunb.edu    1      male            2
# 2            57      6     A  wcjgk@cunb.edu    2    female            1
# 3            57      6     A  mzmqb@cunb.edu    1      male            1
# 4            57      6     A  s6n0y@cunb.edu    1      male            1
# ...         ...    ...   ...             ...  ...       ...          ...
# 1505        946      8     D  jj36e@cunb.edu    1      male            1
# 1506        946      8     D  ca1dg@cunb.edu    1      male            1
# 1507        946      8     D  amdrx@cunb.edu    1      male            1
# 1508        946      8     D  yn5ug@cunb.edu    1      male            2
# 1509        946      8     A  eohgp@cunb.edu    1      male            1
#
#       math_avg   math_t1  language_t1  science_t1   math_t2  language_t2  \
# 0     1.610797  2.046285     2.369783    2.711344  1.175309     1.498807
# 1     7.703944  7.859077     7.206984    6.994455  7.548812     6.896719
# 2     6.649997  7.118976     8.057449    8.573210  6.181019     7.119492
# 3     7.283419  6.973737     7.388008    6.628448  7.593102     8.007373
# 4     7.092971  6.574877     6.773626    7.844316  7.611065     7.809814
# ...        ...       ...          ...         ...       ...          ...
# 1505  5.550397  4.938375     5.306647    4.985917  6.162418     6.530690
# 1506  7.920647  7.661931     8.360153    7.937165  8.179364     8.877586
# 1507  9.011180  9.248758     8.534791    8.056641  8.773601     8.059634
# 1508  6.036111  5.689228     5.071503    5.338547  6.382995     5.765270
# 1509  9.642160  9.768719    10.000000    8.493072  9.515601     9.746882
#
#       science_t2  treatment date_of_birth
# 0       1.840368          1    1997-07-27
# 1       6.684190          1    1997-06-24
# 2       7.635253          1    1997-04-23
# 3       7.247812          1    1997-02-24
# 4       8.880504          1    1996-09-05
# ...          ...        ...           ...
# 1505    6.209960          0    1995-07-04
# 1506    8.454598          0    1995-08-23
# 1507    7.581484          0    1994-12-15
# 1508    6.032315          0    1994-09-18
# 1509    8.239953          0    1994-12-19
#
# [1510 rows x 16 columns]

# %%
def squared(x):
    return x**2


df1['y^2'] = df1.y.apply(lambda x: squared(x)) # inserts column at the end
df1.insert(loc=1, column='x^2', value=df1.x.apply(lambda x: squared(x))) 
df1.insert(loc=2, column='x^4', value=df1.x.apply(lambda x: x**4)) # short function can be written in the apply
df1
# Out:
#        x      x^2     y s  ones    no  na    y^2
# 1    0.0      0.0   1.0       1  None NaN    1.0
# 2    1.0      1.0   2.0       1  None NaN    4.0
# 6   90.0   8100.0  19.0       1  None NaN  361.0
# 7    0.0      0.0   1.0       1  None NaN    1.0
# 8  100.0  10000.0   1.0       1  None NaN    1.0

# %% [markdown]
# ## apply()
# - Row-wise or column-wise operations requiring custom logic or multiple columns.
# - Works on DataFrames (axis=0 for columns, axis=1 for rows).
# - Slower than vectorized operations (Python-level loops).

# %%
df_b["math_extra"] = df_b["math_avg"].apply(lambda x: x**2 if x < 2 else x)
df_b
# Out:
#       school_id  grade class      student_id  sex sex_coded  nationality  \
# 0            57      6     A  wvqgd@cunb.edu    1      male            1
# 1            57      6     A  j0ihe@cunb.edu    1      male            2
# 2            57      6     A  wcjgk@cunb.edu    2    female            1
# 3            57      6     A  mzmqb@cunb.edu    1      male            1
# 4            57      6     A  s6n0y@cunb.edu    1      male            1
# ...         ...    ...   ...             ...  ...       ...          ...
# 1505        946      8     D  jj36e@cunb.edu    1      male            1
# 1506        946      8     D  ca1dg@cunb.edu    1      male            1
# 1507        946      8     D  amdrx@cunb.edu    1      male            1
# 1508        946      8     D  yn5ug@cunb.edu    1      male            2
# 1509        946      8     A  eohgp@cunb.edu    1      male            1
#
#       math_avg   math_t1  language_t1  science_t1   math_t2  language_t2  \
# 0     1.610797  2.046285     2.369783    2.711344  1.175309     1.498807
# 1     7.703944  7.859077     7.206984    6.994455  7.548812     6.896719
# 2     6.649997  7.118976     8.057449    8.573210  6.181019     7.119492
# 3     7.283419  6.973737     7.388008    6.628448  7.593102     8.007373
# 4     7.092971  6.574877     6.773626    7.844316  7.611065     7.809814
# ...        ...       ...          ...         ...       ...          ...
# 1505  5.550397  4.938375     5.306647    4.985917  6.162418     6.530690
# 1506  7.920647  7.661931     8.360153    7.937165  8.179364     8.877586
# 1507  9.011180  9.248758     8.534791    8.056641  8.773601     8.059634
# 1508  6.036111  5.689228     5.071503    5.338547  6.382995     5.765270
# 1509  9.642160  9.768719    10.000000    8.493072  9.515601     9.746882
#
#       science_t2  treatment date_of_birth  math_extra
# 0       1.840368          1    1997-07-27    2.594667
# 1       6.684190          1    1997-06-24    7.703944
# 2       7.635253          1    1997-04-23    6.649997
# 3       7.247812          1    1997-02-24    7.283419
# 4       8.880504          1    1996-09-05    7.092971
# ...          ...        ...           ...         ...
# 1505    6.209960          0    1995-07-04    5.550397
# 1506    8.454598          0    1995-08-23    7.920647
# 1507    7.581484          0    1994-12-15    9.011180
# 1508    6.032315          0    1994-09-18    6.036111
# 1509    8.239953          0    1994-12-19    9.642160
#
# [1510 rows x 17 columns]

# %% [markdown]
# ## applymap()
# - Applies a function row-wise or column-wise to a DataFrame or Series.
# - Works on DataFrames (axis=0 for columns, axis=1 for rows).
# - Use axis=1 (row-wise) sparingly—it’s the slowest.
# - Flexible for complex operations (e.g., custom functions, multiple columns).
# - Row-wise or column-wise operations that can’t be vectorized.
# - Custom functions requiring multiple columns or complex logic.
# - Slower than vectorized operations (Python-level loops).

# %%
def to_uppercase(x):
    if isinstance(x, str):
        return x.upper()
    return x


df = df.applymap(to_uppercase)
# Out:
# Index(['school_id', 'grade', 'class', 'student_id', 'sex', 'nationality',
#        'nationality_coded', 'math_avg', 'math_t1', 'language_t1', 'science_t1',
#        'math_t2', 'language_t2', 'science_t2', 'treatment', 'date_of_birth'],
#       dtype='object')
