# %% [markdown]
# # Selection, Indexing, Filtering

# %%
import pandas as pd

# %%
df = pd.read_csv("https://drive.google.com/uc?id=1oE-3rt17bFW7fOzDIjwFSEMPTIV3NvcO")

# %% [markdown]
# ## Select Columns

# %%
df["grade_language_t1"] # select column by name
df[["sex", "grade_language_t1"]].head() # select columns by name
# Out:
#    sex  grade_language_t1
# 0    1           2.369783
# 1    1           7.206984
# 2    2           8.057449
# 3    1           7.388008
# 4    1           6.773626

# %% [markdown]
# ###  filter()

# %%
# alternative with extra functionality
df.filter(["sex", "grade_language_t1"])
df.filter(items=["sex", "grade"]) # select columns
df.filter(regex="^grade", axis=1) # select columns with "grade" at the start of their name
df.filter(regex="t2$", axis=1) # select columns with "t2" at the end
df.filter(like="math", axis=1) # select columns with "math" in their name
df.filter(regex="^grade") # all columns that start with 'grade'
# Out:
#       grade  grade_math_t1  grade_language_t1  grade_science_t1  \
# 0         6       2.046285           2.369783          2.711344
# 1         6       7.859077           7.206984          6.994455
# 2         6       7.118976           8.057449          8.573210
# 3         6       6.973737           7.388008          6.628448
# 4         6       6.574877           6.773626          7.844316
# ...     ...            ...                ...               ...
# 1505      8       4.938375           5.306647          4.985917
# 1506      8       7.661931           8.360153          7.937165
# 1507      8       9.248758           8.534791          8.056641
# 1508      8       5.689228           5.071503          5.338547
# 1509      8       9.768719          10.000000          8.493072
#
#       grade_math_t2  grade_language_t2  grade_science_t2
# 0          1.175309           1.498807          1.840368
# 1          7.548812           6.896719          6.684190
# 2          6.181019           7.119492          7.635253
# 3          7.593102           8.007373          7.247812
# 4          7.611065           7.809814          8.880504
# ...             ...                ...               ...
# 1505       6.162418           6.530690          6.209960
# 1506       8.179364           8.877586          8.454598
# 1507       8.773601           8.059634          7.581484
# 1508       6.382995           5.765270          6.032315
# 1509       9.515601           9.746882          8.239953
#
# [1510 rows x 7 columns]

# %% [markdown]
# ## Index Rows
# accessing specific positions (rows/cells)

# %%
# loc[] selects by name
df.loc[1509][['school_id', 'grade']] # select row by name
# Out:
# school_id    946
# grade          8
# Name: 1509, dtype: object

# %%
# iloc[] selects by index
df.iloc[1509][:2]  # happens to the same as name
# Out:
# school_id    946
# grade          8
# Name: 1509, dtype: object

# %%
# indexing by row/col name 
df.at[1509, "school_id"]  = 9999  # set value of single cell
df.at[1509, "school_id"]  # single cell
# Out:
# np.int64(9999)

# %%
# indexing by row/col position
df.iat[1509, 3] = "eohgp-ws@cunb.edu" # update value of single cell
df.iat[1509, 3] # row 1509, col 3 (email)
# Out:
# 'eohgp-ws@cunb.edu'

# %%
df.loc[200:204]  # select rows by name sliced -> from : to
df[200:204]  # select rows by index sliced -> from : to

# names in the index
df_id = df.set_index("student_id", drop=True)
df_id.loc[['j0ihe@cunb.edu', 'mzmqb@cunb.edu']]
# df_id.iloc[['j0ihe@cunb.edu', 'mzmqb@cunb.edu']] # does not work because iloc only accepts integer positions

df_id[1:4]
df_id.iloc[1:4]
# Out:
#                 school_id  grade class  sex  nationality  grade_math_t1  \
# student_id
# j0ihe@cunb.edu         57      6     A    1            2       7.859077
# wcjgk@cunb.edu         57      6     A    2            1       7.118976
# mzmqb@cunb.edu         57      6     A    1            1       6.973737
#
#                 grade_language_t1  grade_science_t1  grade_math_t2  \
# student_id
# j0ihe@cunb.edu           7.206984          6.994455       7.548812
# wcjgk@cunb.edu           8.057449          8.573210       6.181019
# mzmqb@cunb.edu           7.388008          6.628448       7.593102
#
#                 grade_language_t2  grade_science_t2  treatment date_of_birth
# student_id
# j0ihe@cunb.edu           6.896719          6.684190          1    1997-06-24
# wcjgk@cunb.edu           7.119492          7.635253          1    1997-04-23
# mzmqb@cunb.edu           8.007373          7.247812          1    1997-02-24

# %% [markdown]
# ### Slicing
# Slicing means getting a range of rows using position

# %%
df.iloc[0:3]  # first 3 rows by index
# slicing rows, columns
df.loc[:2, ["sex", "school_id"]]  # slice of rows and selection of columns
df.loc[:, "sex": "grade_language_t1"]  # get all row from col 'b' & 'c'
df.loc[1:3, "sex": "grade_language_t1"]  # get rows from : to, of columns from:to
df.loc[1:2, :]  # get rows - from : to & all columns
df.iloc[:, -1]  # select last column by index
df.iloc[0:3, :]  #  Slicing Rows and Columns by position
df.iloc[:, 0:3]  # slice columns by index position.
df.iloc[0:2, 1:3]  # slice row and columns by index position.
df.iloc[:2, :2]  # row index 0 to index 1 (exclusive 2), column zero to one
# Out:
#    school_id  grade class      student_id  sex  nationality  grade_math_t1  \
# 0         57      6     A  wvqgd@cunb.edu    1            1       2.046285
# 1         57      6     A  j0ihe@cunb.edu    1            2       7.859077
# 2         57      6     A  wcjgk@cunb.edu    2            1       7.118976
#
#    grade_language_t1  grade_science_t1  grade_math_t2  grade_language_t2  \
# 0           2.369783          2.711344       1.175309           1.498807
# 1           7.206984          6.994455       7.548812           6.896719
# 2           8.057449          8.573210       6.181019           7.119492
#
#    grade_science_t2  treatment date_of_birth
# 0          1.840368          1    1997-07-27
# 1          6.684190          1    1997-06-24
# 2          7.635253          1    1997-04-23

# %% [markdown]
# ## Boolean Indexing

# %%
# df[df["school_id"] == 57]
df[df["school_id"].isin([57, 141])] # multiple values in a column
df[df["date_of_birth"]>"1995-01-01"] # greater than
df[(df["grade_math_t1"] > 9) | (df["school_id"] == 57)] # or
df[(df["grade_math_t1"] > 9) & (df["school_id"] == 57)] # and
# Out:
#     school_id  grade class      student_id  sex  nationality  grade_math_t1  \
# 9          57      6     A  crjpx@cunb.edu    1            1       9.039362
# 18         57      6     B  gca3x@cunb.edu    1            1       9.150260
# 31         57      6     C  0eiwm@cunb.edu    1            1       9.737252
# 81         57      7     C  ysvls@cunb.edu    1            1       9.604527
# 88         57      7     C  7pojk@cunb.edu    1            1       9.267352
# 90         57      7     D  pa9yf@cunb.edu    1            1       9.347091
# 97         57      7     D  tqgis@cunb.edu    1            1      10.000000
#
#     grade_language_t1  grade_science_t1  grade_math_t2  grade_language_t2  \
# 9            9.126943          8.789369       8.235168           8.322749
# 18           9.432889          8.127485       9.523394           9.806023
# 31          10.000000          8.927517      10.000000          10.000000
# 81           8.388494          9.063802      10.000000           9.936316
# 88           8.130984          8.006577      10.000000           9.512149
# 90           9.207399          8.718461       9.562590           9.422897
# 97           8.995439          8.505144      10.000000          10.000000
#
#     grade_science_t2  treatment date_of_birth
# 9           7.985175          1    1996-10-24
# 18          8.500619          0    1997-07-05
# 31          9.194739          1    1997-03-25
# 81         10.000000          0    1996-07-29
# 88          9.387742          0    1996-02-26
# 90          8.933960          1    1996-03-21
# 97          9.760000          1    1995-09-04

# %% [markdown]
# ### between() and loc[] with boolean indexing

# %%
# between function
df[df["grade_language_t1"].between(8.6, 8.7)]


# loc with boolean indexing and choosing columns
df.loc[df.grade_language_t1 > 9, ["school_id", "grade"]] 
df[df.grade_language_t1 > 9][["school_id", "grade"]]
# Out:
#       school_id  grade
# 9            57      6
# 18           57      6
# 19           57      6
# 31           57      6
# 39           57      6
# ...         ...    ...
# 1439        946      7
# 1464        946      8
# 1471        946      8
# 1482        946      8
# 1509       9999      8
#
# [108 rows x 2 columns]

# %% [markdown]
# ### isin() and query() methods

# %%
# if values is a list check whether every value in the DataFrame is present in the list
df[df.isin([57, 0])] 

# check specific column for multiple values
df[df.grade.isin([6, 7])]

# check specific column for multiple values and negate the condition
df[~df.grade.isin([6, 7])]
# Out:
#       school_id  grade class         student_id  sex  nationality  \
# 99           57      8     A     dmv6n@cunb.edu    2            1
# 100          57      8     A     6gola@cunb.edu    2            1
# 101          57      8     A     k8gox@cunb.edu    2            2
# 102          57      8     A     dskjb@cunb.edu    2            1
# 103          57      8     A     1krmv@cunb.edu    2            1
# ...         ...    ...   ...                ...  ...          ...
# 1505        946      8     D     jj36e@cunb.edu    1            1
# 1506        946      8     D     ca1dg@cunb.edu    1            1
# 1507        946      8     D     amdrx@cunb.edu    1            1
# 1508        946      8     D     yn5ug@cunb.edu    1            2
# 1509       9999      8     A  eohgp-ws@cunb.edu    1            1
#
#       grade_math_t1  grade_language_t1  grade_science_t1  grade_math_t2  \
# 99         4.381631           4.923144          5.650331       4.544731
# 100        4.959964           5.541407          5.815619       4.208131
# 101        8.688758           7.802415          7.196903       8.310800
# 102        5.965422           6.225083          4.964288       5.603122
# 103        5.488107           6.166542          5.126704       4.649922
# ...             ...                ...               ...            ...
# 1505       4.938375           5.306647          4.985917       6.162418
# 1506       7.661931           8.360153          7.937165       8.179364
# 1507       9.248758           8.534791          8.056641       8.773601
# 1508       5.689228           5.071503          5.338547       6.382995
# 1509       9.768719          10.000000          8.493072       9.515601
#
#       grade_language_t2  grade_science_t2  treatment date_of_birth
# 99             5.086245          5.813431          0    1995-06-28
# 100            4.789574          5.063786          0    1995-04-01
# 101            7.424457          6.818945          0    1995-05-24
# 102            5.862782          4.601988          0    1995-01-22
# 103            5.328358          4.288519          0    1994-09-25
# ...                 ...               ...        ...           ...
# 1505           6.530690          6.209960          0    1995-07-04
# 1506           8.877586          8.454598          0    1995-08-23
# 1507           8.059634          7.581484          0    1994-12-15
# 1508           5.765270          6.032315          0    1994-09-18
# 1509           9.746882          8.239953          0    1994-12-19
#
# [533 rows x 14 columns]

# %% [markdown]
# ### query()

# %%
df[df.grade_math_t1 > df.grade_math_t2]
df.query("grade_math_t1 > grade_math_t2")[["grade_math_t1", "grade_math_t2"]].round(2)
# Out:
#       grade_math_t1  grade_math_t2
# 0              2.05           1.18
# 1              7.86           7.55
# 2              7.12           6.18
# 5              7.04           6.27
# 6              8.61           7.64
# ...             ...            ...
# 1502           7.93           6.01
# 1503           6.55           4.89
# 1504           6.56           6.19
# 1507           9.25           8.77
# 1509           9.77           9.52
#
# [606 rows x 2 columns]

# %%
# query can be cleaner for complex queries - keyword class needs backticks in query
# df[(df.sex == 1) & (df["class"] == "C") & ((df.grade_math_t1 > 9.9) | (df.grade_math_t2 > 9.9))]
df.query("sex == 1 & `class` == 'C' & (grade_math_t1 > 9.9 | grade_math_t2 > 9.9)")
# Out:
#       school_id  grade class      student_id  sex  nationality  grade_math_t1  \
# 31           57      6     C  0eiwm@cunb.edu    1            1       9.737252
# 35           57      6     C  wbcfx@cunb.edu    1            2       6.940615
# 81           57      7     C  ysvls@cunb.edu    1            1       9.604527
# 88           57      7     C  7pojk@cunb.edu    1            1       9.267352
# 137          57      8     C  yxxfv@cunb.edu    1            1       8.631280
# 373         141      7     C  6zo9s@cunb.edu    1            2       9.207145
# 383         141      7     C  2hbgs@cunb.edu    1            2       7.348327
# 419         141      8     C  144ga@cunb.edu    1            1       9.237515
# 421         141      8     C  5xeof@cunb.edu    1            1       9.135011
# 527         262      7     C  nq45z@cunb.edu    1            1       8.823036
# 579         262      8     C  inrty@cunb.edu    1            1       8.504132
# 669         426      7     C  gxssl@cunb.edu    1            1       8.926202
# 671         426      7     C  mseow@cunb.edu    1            1       8.231856
# 733         426      8     C  kdlts@cunb.edu    1            2       7.468656
# 970         499      7     C  arw8m@cunb.edu    1            1       9.624094
# 971         499      7     C  rsvdo@cunb.edu    1            2       7.750984
# 974         499      7     C  e8ypj@cunb.edu    1            2       7.050909
# 976         499      7     C  x016s@cunb.edu    1            1      10.000000
# 1082        812      6     C  nye4a@cunb.edu    1            1       9.561568
# 1135        812      7     C  ujwt4@cunb.edu    1            1       9.046869
# 1136        812      7     C  2wfqx@cunb.edu    1            1       9.223794
# 1239        881      6     C  maxy2@cunb.edu    1            1       8.930415
#
#       grade_language_t1  grade_science_t1  grade_math_t2  grade_language_t2  \
# 31            10.000000          8.927517           10.0          10.000000
# 35             6.494307          6.535804           10.0           9.664280
# 81             8.388494          9.063802           10.0           9.936316
# 88             8.130984          8.006577           10.0           9.512149
# 137            8.390752          8.124870           10.0          10.000000
# 373            8.833523          8.292497           10.0          10.000000
# 383            6.862350          5.577604           10.0          10.000000
# 419           10.000000          8.414176           10.0          10.000000
# 421            8.841103          9.407451           10.0           9.866440
# 527            8.724362          8.356688           10.0          10.000000
# 579            8.737318          7.577565           10.0          10.000000
# 669            8.583355          9.375213           10.0           9.668802
# 671            9.280767          7.712725           10.0          10.000000
# 733            8.414136          9.020312           10.0          10.000000
# 970            8.536750          9.622638           10.0           9.841537
# 971            7.710657          9.417058           10.0          10.000000
# 974            6.689119          6.588267           10.0          10.000000
# 976           10.000000         10.000000           10.0          10.000000
# 1082          10.000000         10.000000           10.0          10.000000
# 1135           8.313388          9.353481           10.0           9.420835
# 1136           8.957487          9.851779           10.0          10.000000
# 1239           9.212198          8.912495           10.0          10.000000
#
#       grade_science_t2  treatment date_of_birth
# 31            9.194739          1    1997-03-25
# 35            9.705778          1    1996-10-24
# 81           10.000000          0    1996-07-29
# 88            9.387742          0    1996-02-26
# 137          10.000000          1    1995-06-03
# 373          10.000000          1    1996-05-05
# 383           9.297259          1    1996-01-14
# 419           9.433997          0    1994-11-12
# 421          10.000000          0    1994-12-29
# 527           9.864914          1    1996-08-15
# 579           9.576957          0    1995-06-03
# 669          10.000000          0    1996-08-18
# 671           9.669151          0    1996-03-30
# 733          10.000000          1    1994-11-19
# 970          10.000000          1    1996-07-20
# 971          10.000000          1    1995-12-29
# 974          10.000000          1    1996-03-29
# 976          10.000000          1    1996-03-28
# 1082         10.000000          1    1997-03-09
# 1135         10.000000          1    1996-08-24
# 1136         10.000000          1    1996-05-29
# 1239         10.000000          1    1997-03-15

# %% [markdown]
# ### xs()
# Return cross-section from a particular level of a MultiIndex.

# %%
d = {
     "num_legs": [4, 4, 2, 2],
     "num_wings": [0, 0, 2, 2],
     "class": ["mammal", "mammal", "mammal", "bird"],
     "animal": ["cat", "dog", "bat", "penguin"],
     "locomotion": ["walks", "walks", "flies", "walks"],
 }

df = pd.DataFrame(data=d)
# three index levels
df = df.set_index(["class", "animal", "locomotion"])
df.sort_index(level=2, inplace=True)  # sort by first index level
df
# Out:
#                            num_legs  num_wings
# class  animal  locomotion
# mammal bat     flies              2          2
# bird   penguin walks              2          2
# mammal cat     walks              4          0
#        dog     walks              4          0

# %%
df.xs("mammal") # get all mammals
df.xs(("mammal", "dog")) # get all info about dogs
df.xs(("mammal", "dog", "walks")) # get specific info about dogs
# Out:
# /tmp/ipykernel_30595/1720633188.py:2: PerformanceWarning: indexing past lexsort depth may impact performance.
#   df.xs(("mammal", "dog")) # get all info about dogs
# num_legs     4
# num_wings    0
# Name: (mammal, dog, walks), dtype: int64

# %%
# axis=1 means columns
df.xs("num_wings", axis=1) # returns this column


df.xs("mammal", level=0) # level of the index
df.xs("dog", level="animal")

# multiple levels one by index and one by name
df.xs(("bird", "walks"), level=[0, "locomotion"])
