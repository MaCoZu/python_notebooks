# %%
import pandas as pd

# %%
df = pd.read_csv("https://drive.google.com/uc?id=1oE-3rt17bFW7fOzDIjwFSEMPTIV3NvcO")
df
# Out:
#       school_id  grade class      student_id  sex  nationality  grade_math_t1  \
# 0            57      6     A  wvqgd@cunb.edu    1            1       2.046285
# 1            57      6     A  j0ihe@cunb.edu    1            2       7.859077
# 2            57      6     A  wcjgk@cunb.edu    2            1       7.118976
# 3            57      6     A  mzmqb@cunb.edu    1            1       6.973737
# 4            57      6     A  s6n0y@cunb.edu    1            1       6.574877
# ...         ...    ...   ...             ...  ...          ...            ...
# 1505        946      8     D  jj36e@cunb.edu    1            1       4.938375
# 1506        946      8     D  ca1dg@cunb.edu    1            1       7.661931
# 1507        946      8     D  amdrx@cunb.edu    1            1       9.248758
# 1508        946      8     D  yn5ug@cunb.edu    1            2       5.689228
# 1509        946      8     A  eohgp@cunb.edu    1            1       9.768719
#
# ...

# %% [markdown]
# ## group
#
# <details>
#
# The Pandas groupby method uses a process known as split, apply, and combine to provide useful aggregations or modifications to your DataFrame. This process works as just as its called:
#
# - **Splitting** the data into groups based on some criteria
# - **Applying** a function to each group independently
# - **Combing** the results into an appropriate data structure
# </details>

# %%
# df.groupby('school_id')
# df.groupby('school_id').ngroups
# df.groupby('school_id').groups
# df.groupby('school_id').groups.keys()
# df.groupby('school_id').get_group(141)
# df.groupby('school_id').count()
df.groupby("school_id")["student_id"].count()
df.groupby("school_id")["grade_math_t1"].mean().sort_values(ascending=False).round(2)
# Out:
# school_id
# 946    6.81
# 141    6.73
# 499    6.72
# 881    6.70
# 812    6.69
# 458    6.61
# 262    6.59
# 426    6.59
# 60     6.57
# 57     6.53
# Name: grade_math_t1, dtype: float64

# %% [markdown]
# ## Filtering

# %%
df[df["grade_math_t1"] > 7]
df[df["grade_math_t1"] > 7][["student_id", "grade_math_t1"]]
df[df["grade_math_t1"] > 7][["student_id", "grade_math_t1"]].sort_values("grade_math_t1", ascending=False).head(3)
# Out:
#           student_id  grade_math_t1
# 1364  8vmwt@cunb.edu           10.0
# 97    tqgis@cunb.edu           10.0
# 451   swejn@cunb.edu           10.0

# %%
df[(df["grade_math_t1"] > 9.7) & (df["grade_math_t2"] > 9.7)]
# Out:
#       school_id  grade class      student_id  sex  nationality  grade_math_t1  \
# 31           57      6     C  0eiwm@cunb.edu    1            1       9.737252
# 97           57      7     D  tqgis@cunb.edu    1            1      10.000000
# 451         262      6     A  swejn@cunb.edu    1            1      10.000000
# 740         426      8     D  hb3cd@cunb.edu    1            1       9.700488
# 900         499      6     B  c0ivs@cunb.edu    1            1       9.784993
# 976         499      7     C  x016s@cunb.edu    1            1      10.000000
# 983         499      7     D  4wurs@cunb.edu    1            1       9.786573
# 1209        881      6     A  35q5v@cunb.edu    1            1       9.718762
# 1370        946      6     A  j9ny8@cunb.edu    1            1       9.972244
# 1469        946      8     A  9zjxw@cunb.edu    1            1       9.726560
# 1471        946      8     A  opwwd@cunb.edu    1            1       9.931566
#
# ...

# %%
df_f = df[(df["sex"] == 2)  &  (df["grade_math_t1"] > 9) & (df["grade_math_t2"] > 9)]
df_m = df[(df["sex"] == 1)  &  (df["grade_math_t1"] > 9.7) & (df["grade_math_t2"] > 9.7)]

# %%
# df_fm = pd.concat([df_f, df_m]).sort_index() # df.append deprecated
df_fm2 = df_fm.reset_index(drop=True)
df_fm2
# Out:
#     school_id  grade class      student_id  sex  nationality  grade_math_t1  \
# 0          57      6     C  0eiwm@cunb.edu    1            1       9.737252
# 1          57      7     D  tqgis@cunb.edu    1            1      10.000000
# 2         141      6     B  4xcir@cunb.edu    2            1       9.052874
# 3         141      7     D  d1vbx@cunb.edu    2            1       9.370844
# 4         262      6     A  swejn@cunb.edu    1            1      10.000000
# 5         262      6     D  z73xp@cunb.edu    2            1       9.414306
# 6         426      6     D  fc3yb@cunb.edu    2            1       9.036513
# 7         426      8     C  pfxhr@cunb.edu    2            1       9.209376
# 8         426      8     D  hb3cd@cunb.edu    1            1       9.700488
# 9         458      7     A  cm7tj@cunb.edu    2            1       9.726741
# 10        499      6     B  c0ivs@cunb.edu    1            1       9.784993
# ...
